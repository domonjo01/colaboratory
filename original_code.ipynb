# %% [markdown]
# <a href="https://colab.research.google.com/github/domonjo01/colaboratory/blob/master/original_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# データ：身長
matrix = np.array([165, 160, 166, 164, 168, 164,168, 169,169, 166],)

# データをソート：昇順
sorted_matrix = np.sort(matrix)

# 偏差
deviation = sorted_matrix - np.mean(matrix)

# 偏差の二乗（np.roundで四捨五入）
deviation_squared = np.round(deviation ** 2, 2)

# 平均
average = np.sum(sorted_matrix) / len(sorted_matrix)

# 偏差の2乗の和
sum_deviation_squared = np.sum(deviation_squared)

# 分散：偏差の和 / 個数（偏差の和の平均）
variance= np.sum(sum_deviation_squared) / len(sorted_matrix)

# 標準偏差
standard_deviation = np.sqrt(variance)

# 出力
print(f"身長： {sorted_matrix}")
print(f"偏差： {deviation}")
print(f"平均： {average}")
print(f"偏差の2乗： {deviation_squared}")
print(f"偏差の2乗の和： {sum_deviation_squared}")
print(f"標準偏差： {standard_deviation}")

# 関数出力
print("平均：" + str(np.mean(sorted_matrix)))
print("分散の和：" + str(np.var(sorted_matrix)))
print("標準偏差：" + str(np.std(sorted_matrix)))
# Out:
# 身長： [160 164 164 165 166 166 168 168 169 169]
# 偏差： [-5.9 -1.9 -1.9 -0.9  0.1  0.1  2.1  2.1  3.1  3.1]
# 平均： 165.9
# 偏差の2乗： [3.481e+01 3.610e+00 3.610e+00 8.100e-01 1.000e-02 1.000e-02 4.410e+00
#  4.410e+00 9.610e+00 9.610e+00]
# 偏差の2乗の和： 70.89999999999999
# 標準偏差： 2.662705391138869
# 平均：165.9
# 分散の和：7.089999999999999
# 標準偏差：2.662705391138869
